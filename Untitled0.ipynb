# %% [markdown]
# <a href="https://colab.research.google.com/github/GreyIM94/home_work/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['sqft_living'], bins=30, edgecolor='black')
plt.title('Распределение жилой площади')
plt.xlabel('Жилая площадь (sqft)')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['yr_built'], bins=30, edgecolor='black')
plt.title('Распределение года постройки')
plt.xlabel('Год постройки')
plt.ylabel('Количество домов')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
data['waterfront']. value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Распределение домов по наличию виду на набережную')
plt.xlabel('Вид на набережную')
plt.ylabel('Количество домов')
plt.xticks([0, 1], ['Нет', 'Да'], rotation=0)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8,5))
data['floors'].value_counts().sort_index().plot(kind='bar', color='lightgreen')
plt.title('Распределение этажей домов')
plt.xlabel('Количество этажей')
plt.ylabel('Количество домов')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(8, 5))
data['condition'].value_counts().sort_index().plot(kind='bar', color='coral')
plt.title('Распределение состояния домов')
plt.xlabel('Состояние домов')
plt.ylabel('Количество домов')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(data['bedrooms'], data['price'], alpha=0.5, color='blue')
plt.title('Цена недвижимости в зависимости от количества спален')
plt.xlabel('Количество спален')
plt.ylabel('Цена (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.boxplot([data[data['condition'] == i]['price'] for i in sorted (data['condition'].unique())])
plt.title('Цена недвижимости в зависимости от состояния')
plt.xlabel('Состояние')
plt.ylabel('Цена (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.boxplot([data[data['floors'] == i]['price'] for i in sorted (data['floors'].unique())], labels = sorted(data['floors'].unique()))
plt.title('Цена недвижимости в зависимости от этажности')
plt.xlabel('Количество Этажность')
plt.ylabel('Цена (USD)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
data.boxplot(column='price', by='waterfront',grid=False)
plt.title('Цена недвижимости в зависимости от вида на набережную')
plt.suptitle('')
plt.xlabel('Вид на набережную')
plt.ylabel('Цена (USD)')
plt.xticks([1,2], ['ДА', 'НЕТ'])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(data['sqft_living'], data['price'], alpha=0.5, color='green')
plt.title('Цена недвижимости в зависимости от жилой площади')
plt.xlabel('Жилая площадь (sqft)')
plt.ylabel('Цена (USD)')
plt.grid(True)
plt.show()
